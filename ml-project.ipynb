# %% [markdown]
# For running remotely on Kaggle or Collab:

# %%
# !git clone https://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@github.com/HHHMGK/ML-project.git
# %cd ML-project/

# %% [markdown]
# Install requirements:

# %%
# !python -m pip install -r requirements.txt

# %% [markdown]
# Show main.py parameters:

# %%
# !python main.py -h

# %% [markdown]
# # Train and Test at once

# %% [markdown]
# For running local with machine with equal or less than 4GB VRAM, please use `--batch_size 8` or less.

# %%
# !python main.py train_test --title_model LSTM --poster_model DenseNet169  --urating_model FNN --use_dropped_data False --batch_size 32  --image_size 256 --max_epochs 20 --checkpoint lstm_den169_fnn_nodrop

# %% [markdown]
# # Training

# %%
# !python main.py train --title_model LSTM --poster_model DenseNet169  --urating_model FNN --use_dropped_data False --batch_size 32  --image_size 256 --max_epochs 20 --checkpoint lstm_den169_fnn_nodrop

# %% [markdown]
# # Testing

# %% [markdown]
# Testing with lastest model in 'model/saved_models' folder
# FINAL.ckpt is the lastest model

# %%
# !python main.py test --title_model LSTM --poster_model DenseNet169  --urating_model FNN --use_dropped_data False --batch_size 32  --image_size 256 --max_epochs 20 --checkpoint lstm_den169_fnn_nodrop
